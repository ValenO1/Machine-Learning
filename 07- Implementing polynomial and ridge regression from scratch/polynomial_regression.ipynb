# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt
from linear_model import RidgeRegression

# %%
data = pd.read_csv("polynomial_data.csv")
data
# Out:
#            x          y
# 0   0.749080   2.116535
# 1   1.901429  26.002897
# 2   1.463988  13.009634
# 3   1.197317  -3.072104
# 4   0.312037  -0.976831
# ..       ...        ...
# 95  0.987591  -0.226117
# 96  1.045466   4.185261
# 97  0.855082   4.206585
# 98  0.050838   1.383980
# 99  0.215783   4.176106
#
# [100 rows x 2 columns]

# %%
X = data[["x"]]
y = data["y"]
plt.scatter(X,y)

# %%
model = LinearRegression()
model.fit(X,y)
model.score(X,y)
# Out:
# 0.5924022914402727

# %%
y_pred = model.predict(X)
plt.scatter(X,y)
plt.plot(X,y_pred)

# %%
poly = PolynomialFeatures(include_bias=False, degree=10)
new_x = poly.fit_transform(X)

# %%
model = LinearRegression()
model.fit(new_x, y)
model.score(new_x, y)
# Out:
# 0.8036987083985089

# %%
X_range = np.linspace(0,2, 100).reshape(100,1)
X_range_poly = poly.fit_transform(X_range)

# %%
y_pred = model.predict(X_range_poly)
plt.scatter(X,y)
plt.plot(X_range, y_pred, c="red")

# %%
model = RidgeRegression(alpha=2)
model.fit(new_x, y)
model.score(new_x, y)
model.betas
# Out:
# array([ 1.8294405 , -1.49276643, -0.60477875,  0.13164466,  0.6459816 ,
#         0.92396833,  0.91560042,  0.56566578, -0.0976256 , -0.69982605,
#         0.23914811])

# %%
y_pred = model.predict(X_range_poly)
plt.scatter(X,y)
plt.plot(X_range, y_pred, c="red")

# %%
from sklearn.linear_model import Ridge
model = Ridge(alpha=2)
model.fit(new_x, y)
model.score(new_x, y)
model.coef_
# Out:
# array([-1.49276643, -0.60477874,  0.13164466,  0.6459816 ,  0.92396833,
#         0.91560042,  0.56566578, -0.0976256 , -0.69982605,  0.23914811])

# %%
model.intercept_
# Out:
# 1.8294404993540194

# %%
y_pred = model.predict(X_range_poly)
plt.scatter(X,y)
plt.plot(X_range, y_pred, c="red")
