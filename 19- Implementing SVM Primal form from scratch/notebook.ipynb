# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier
from svm import LinearSVM

# %%
data = pd.read_csv("separable data.csv")
data
# Out:
#     petal length (cm)  petal width (cm)  class
# 0                 1.4               0.2      0
# 1                 1.4               0.2      0
# 2                 1.3               0.2      0
# 3                 1.5               0.2      0
# 4                 1.4               0.2      0
# ..                ...               ...    ...
# 95                4.2               1.2      1
# 96                4.2               1.3      1
# 97                4.3               1.3      1
# 98                3.0               1.1      1
# 99                4.1               1.3      1
#
# [100 rows x 3 columns]

# %%
X = data.drop("class", axis=1).values
y = data["class"].values
y = np.where(y == 1, 1, -1)

# %%
plt.scatter(X[:, 0], X[:, 1], c = y)

# %%
model = LinearSVM()
model.fit(X,y)
model.score(X,y)
# Out:
# 1.0

# %%
plt.scatter(X[:, 0], X[:, 1], c = y, cmap= plt.cm.coolwarm)
plt.xlabel("feature 1")
plt.ylabel("feature 2")
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.linspace(x_min,x_max, 1000), np.linspace(y_min,y_max, 1000))

z = model.predict(np.c_[xx.flatten(), yy.ravel()])
z = z.reshape(xx.shape)
plt.contourf(xx, yy, z, alpha = .2, cmap = plt.cm.coolwarm)

# %%
model2 = LinearSVC(dual= False)
model2.fit(X,y)
model2.score(X,y)
# Out:
# 1.0

# %%
plt.scatter(X[:, 0], X[:, 1], c = y, cmap= plt.cm.coolwarm)
plt.xlabel("feature 1")
plt.ylabel("feature 2")
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.linspace(x_min,x_max, 1000), np.linspace(y_min,y_max, 1000))

z = model2.predict(np.c_[xx.flatten(), yy.ravel()])
z = z.reshape(xx.shape)
plt.contourf(xx, yy, z, alpha = .2, cmap = plt.cm.coolwarm)

# %%
model3 = SGDClassifier(loss="hinge")
model3.fit(X,y)
model3.score(X,y)
# Out:
# 1.0

# %%
plt.scatter(X[:, 0], X[:, 1], c = y, cmap= plt.cm.coolwarm)
plt.xlabel("feature 1")
plt.ylabel("feature 2")
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.linspace(x_min,x_max, 1000), np.linspace(y_min,y_max, 1000))

z = model3.predict(np.c_[xx.flatten(), yy.ravel()])
z = z.reshape(xx.shape)
plt.contourf(xx, yy, z, alpha = .2, cmap = plt.cm.coolwarm)

# %%
data2 = pd.read_csv("non separable data.csv")
data2
# Out:
#      Feature 1  Feature 2  Label
# 0     3.764052   2.400157    0.0
# 1     2.978738   4.240893    0.0
# 2     3.867558   1.022722    0.0
# 3     2.950088   1.848643    0.0
# 4     1.896781   2.410599    0.0
# ..         ...        ...    ...
# 495   0.441033   0.178793    1.0
# 496  -0.799422   0.240788    1.0
# 497   0.289121   0.412871    1.0
# 498  -0.198399   0.094192    1.0
# 499  -1.147611  -0.358114    1.0
#
# [500 rows x 3 columns]

# %%
X = data2.drop("Label", axis=1).values
y = data2["Label"].values
y = np.where(y == 1, 1, -1)

# %%
plt.scatter(X[:, 0], X[:, 1], c = y, cmap= plt.cm.coolwarm)
plt.xlabel("feature 1")
plt.ylabel("feature 2")
# Out:
# Text(0, 0.5, 'feature 2')

# %%
model4 = LinearSVM(C = 1)
model4.fit(X,y)
model4.score(X,y)
# Out:
# 0.96

# %%
plt.scatter(X[:, 0], X[:, 1], c = y, cmap= plt.cm.coolwarm)
plt.xlabel("feature 1")
plt.ylabel("feature 2")
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.linspace(x_min,x_max, 1000), np.linspace(y_min,y_max, 1000))

z = model4.predict(np.c_[xx.flatten(), yy.ravel()])
z = z.reshape(xx.shape)
plt.contourf(xx, yy, z, alpha = .2, cmap = plt.cm.coolwarm)

# %%
model5 = LinearSVC(dual= False)
model5.fit(X,y)
model5.score(X,y)
# Out:
# 0.962

# %%
plt.scatter(X[:, 0], X[:, 1], c = y, cmap= plt.cm.coolwarm)
plt.xlabel("feature 1")
plt.ylabel("feature 2")
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.linspace(x_min,x_max, 1000), np.linspace(y_min,y_max, 1000))

z = model5.predict(np.c_[xx.flatten(), yy.ravel()])
z = z.reshape(xx.shape)
plt.contourf(xx, yy, z, alpha = .2, cmap = plt.cm.coolwarm)

# %%
model6 = SGDClassifier(loss="hinge")
model6.fit(X,y)
model6.score(X,y)
# Out:
# 0.95

# %%
plt.scatter(X[:, 0], X[:, 1], c = y, cmap= plt.cm.coolwarm)
plt.xlabel("feature 1")
plt.ylabel("feature 2")
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.linspace(x_min,x_max, 1000), np.linspace(y_min,y_max, 1000))

z = model6.predict(np.c_[xx.flatten(), yy.ravel()])
z = z.reshape(xx.shape)
plt.contourf(xx, yy, z, alpha = .2, cmap = plt.cm.coolwarm)
